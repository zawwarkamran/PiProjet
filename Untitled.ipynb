# %%
conda install -c conda-forge opencv
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                           \                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [1:26:43<29:43:45, 331.35s/i/                                                                                                                                                                     | lint pycrypto bokeh nltk pandocfilters cryptography pywavelets sqlalchemy importlib_metadata anaconda-navigator curl opencv distributed r-pki bottleneck contextlib2 pytest atomicwrites html5lib pexpect pyyaml sympy cython backports.shutil_get_terminal_size multipledispatch imageio mkl_fft backports.functools_lru_cache pytables colorama libcurl matplotlib parso python conda-package-handling pyflakes bkcharts markupsafe conda requests sphinxcontrib-websupport pillow setuptools et_xmlfile rope future partd python-libarchive-c bitarray commonmark openssl sphinxcontrib lazy-object-proxy pyqt backports wrapt lxml llvmlite xlwings jupyter_console zict greenlet pycparser soupsieve qtconsole _ipyw_jlab_nb_ext_conf kiwisolver pycosat ipykernel pathlib2 keyring olefile mkl-service pycodestyle krb5 astroid cachecontrol flask networkx idna pep8 pyqtgraph asn1crypto path.py r-base python-louvain isort notebook numpydoc xlwt mpmath webencodings decorator keyrings.alt widgetsnbextension navigator-updater sphinx conda-env boto anyqt ipython lockfile nbformat anaconda-client qtawesome cloudpickle ca-certificates appnope ruamel_yaml spyder py-lief gmpy2 conda-verify cytoolz backcall:  10%| | 41/414 [27:59<47:19,  7.61s/it]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   -  entrypoints sortedcollections jsonschema pytest-remotedata backports.os filelock docutils pysocks jdcal tblib unicodecsv simplegeneric traitlets xlrd msgpack-python wurlitzer locket pyrsistent pickleshare orange3 sphinxcontr ...
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - anaconda-navigator -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - anaconda-project -> python[version='3.4.*|>=3.8,<3.9.0a0']
#   - anaconda==2019.10 -> python[version='2.7.16|3.6.9|3.7.4',build='h359304d_0|h97142e2_7|h359304d_1']
#   - astropy -> python=3.4
#   - autograd -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - backports.functools_lru_cache -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=2.7,<2.8.0a0']
#   - bkcharts -> python=3.4
#   - bleach -> python[version='>=3.8,<3.9.0a0']
#   - cachecontrol -> python[version='2.7.*|3.5.*|3.6.*|>=3.8,<3.9.0a0|3.4.*']
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.9|>=2.7,<2.8.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|3.4.*',build=0_73_pypy]
#   - commonmark -> python[version='>=3.8,<3.9.0a0']
#   - conda-env -> python[version='2.7.*|3.4.*|3.5.*']
#   - cryptography -> python[version='3.4.*|3.6.9|<=3.3|3.7.*|3.8.*',build=0_73_pypy]
#   - gevent -> python[version='3.4.*|3.6.9',build=0_73_pypy]
#   - h5py -> python[version='<3']
#   - html5lib -> python[version='3.4.*|>=3.8,<3.9.0a0']
#   - jinja2 -> python[version='>=3.8,<3.9.0a0']
#   - joblib -> python[version='>=3.8,<3.9.0a0']
#   - jupyterlab -> python[version='>=3.8,<3.9.0a0']
#   - jupyterlab_server -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.8,<3.9.0a0|3.4.*']
#   - matplotlib -> python[version='3.6.*|<3']
#   - mkl-service -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - mkl_fft -> python=3.4
#   - mkl_random -> python=3.4
#   - more-itertools -> python=3.4
#   - navigator-updater -> python[version='2.7.*|3.5.*|3.6.*|>=3.8,<3.9.0a0|3.4.*']
#   - networkx -> python[version='>=3.8,<3.9.0a0']
#   - numba -> python=3.4
#   - opencv -> python[version='>=3.8,<3.9.0a0']
#   - openpyxl -> python[version='>=3.8,<3.9.0a0']
#   - packaging -> python[version='>=3.8,<3.9.0a0']
#   - partd -> python[version='>=3.8,<3.9.0a0']
#   - path.py -> python[version='>=3.8,<3.9.0a0']
#   - prometheus_client -> python[version='>=3.8,<3.9.0a0']
#   - pygments -> python[version='>=3.8,<3.9.0a0']
#   - pyqtgraph -> python[version='>=3.8,<3.9.0a0']
#   - pytest-arraydiff -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - pytest-doctestplus -> python[version='2.7.*|3.5.*|3.6.*|>=3.8,<3.9.0a0|3.4.*']
#   - pytest-openfiles -> python[version='2.7.*|3.5.*|3.6.*|>=3.8,<3.9.0a0|3.4.*']
#   - pytest-remotedata -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - python-dateutil -> python[version='>=3.8,<3.9.0a0']
#   - qtawesome -> python[version='>=3.8,<3.9.0a0']
#   - seaborn -> python[version='>=3.8,<3.9.0a0']
#   - serverfiles -> python[version='2.7.*|3.5.*|3.6.*|3.4.*']
#   - sortedcollections -> python[version='>=3.8,<3.9.0a0']
#   - sphinx -> python[version='>=3.8,<3.9.0a0']
#   - sphinxcontrib-websupport -> python[version='>=3.8,<3.9.0a0']
#   - testpath -> python[version='3.4.*|>=3.8,<3.9.0a0']
#   - zict -> python[version='>=3.8,<3.9.0a0']
#
# Your python: python=3.7
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package freetype conflicts for:
# r-xml2 -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# nltk -> matplotlib -> freetype[version='2.6.*|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-openssl -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-forge -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# anaconda==2019.10 -> matplotlib==3.1.1=py36h54f8f79_0 -> freetype[version='>=2.9.1,<3.0a0']
# r-curl -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-mime -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-hms -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-dplyr -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-markdown -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# opencv -> ffmpeg[version='>=4.0.2,<4.1.0a0'] -> freetype[version='2.6.*|2.7|2.7.*|2.8.1|>=2.8.1,<2.9.0a0|>=2.8,<2.9.0a0|>=2.8.1,<2.8.2.0a0|2.8.1.*']
# r-blob -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# bokeh -> pillow[version='>=4.0'] -> freetype[version='2.6.*|2.7|2.7.*|2.7|2.8.*|2.8.1|2.8.1.*|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-rcpp -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-xtable -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-httr -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-tidyselect -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-bitops -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-catools -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-readxl -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-withr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# scikit-image -> matplotlib-base[version='>=2.0.0'] -> freetype[version='2.5.*|2.6.*|2.7|2.8.*|2.8.1|2.8.1.*|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0|2.7|2.7.*']
# orange3==3.23.0 -> matplotlib[version='>=2.0.0'] -> freetype[version='>=2.8,<2.9.0a0|>=2.9.1,<3.0a0']
# seaborn -> matplotlib-base[version='>=2.1.2'] -> freetype[version='2.6.*|>=2.8,<2.9.0a0|>=2.9.1,<3.0a0']
# r-cli -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rmarkdown -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-packrat -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-base64enc -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rjsonio -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-promises -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# pillow -> freetype[version='2.5.*|2.6.*|2.7|2.7.*|2.7|2.8.*|2.8.1|2.8.1.*|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-highr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rematch -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-bit64 -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# anaconda-navigator -> pillow -> freetype[version='2.5.*|2.6.*|2.7|2.7.*|2.7|2.8.*|2.8.1|2.8.1.*|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-rprojroot -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-haven -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rappdirs -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-yaml -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-stringr -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-dbi -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-r2d3 -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-sparklyr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rjdbc -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-generics -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rcurl -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-config -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-xfun -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# harfbuzz -> cairo=1.14 -> freetype==2.7
# r-plogr -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-tinytex -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# fontconfig -> freetype[version='2.6.*|2.7|2.7.*|2.7|2.8.1|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.9,<3.0a0|>=2.8,<2.9.0a0']
# r-bit -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-dbplyr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-cellranger -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-htmltools -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-odbc -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-readr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# pango -> fontconfig[version='>=2.13.0,<3.0a0'] -> freetype[version='2.7|>=2.9,<3.0a0']
# r-magrittr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-shiny -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-bh -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-progress -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-utf8 -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-tibble -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# imageio -> pillow -> freetype[version='2.5.*|2.6.*|2.7|2.7.*|2.7|2.8.*|2.8.1|2.8.1.*|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-digest -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-sourcetools -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-httpuv -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-ellipsis -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-htmlwidgets -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-backports -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# anaconda==2019.10 -> freetype==2.9.1=hb4e5f40_0
# r-profvis -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# matplotlib -> freetype[version='2.6.*|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-fansi -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# cairo -> freetype[version='2.6.*|2.7|2.7.*|2.7|2.8.1|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# cairo -> fontconfig[version='>=2.13.0,<3.0a0'] -> freetype[version='>=2.9,<3.0a0']
# r-tidyr -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-clipr -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rjava -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-miniui -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rsconnect -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-base -> pango[version='>=1.40.14,<1.41.0a0'] -> freetype[version='2.6.*|2.7.*|2.7|2.7.*|2.8.1|>=2.8.1,<2.9.0a0|>=2.8,<2.9.0a0']
# r-pkgconfig -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-forcats -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-later -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# pango -> freetype[version='2.6.*|2.7.*|2.7|2.7.*|2.8.1|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-pki -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-stringi -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-jsonlite -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# rstudio==1.1.456 -> freetype[version='>=2.9.1']
# r-knitr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rlang -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-glue -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-prettyunits -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# harfbuzz -> freetype[version='2.6.*|2.7|2.7.*|2.8.1|>=2.8.1,<2.9.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-evaluate -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# opencv -> freetype[version='>=2.9.1,<3.0a0']
# r-mongolite -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# orange-widget-base -> matplotlib-base -> freetype[version='2.6.*|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# r-crayon -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-rstudioapi -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-sys -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-askpass -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-base -> freetype[version='>=2.9.1,<3.0a0']
# r-pillar -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-assertthat -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-purrr -> r-base[version='>=3.6,<3.7.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
# r-r6 -> r-base[version='>=3.5,<3.6.0a0'] -> freetype[version='>=2.9.1,<3.0a0']
#
# Package libgfortran conflicts for:
# r-mime -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-bh -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# pytest-arraydiff -> numpy -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-blob -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# numpy -> libblas[version='>=3.8.0,<4.0a0'] -> libgfortran[version='>=4.0.0,<5.0.0.a0']
# r-pillar -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-tibble -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-config -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-evaluate -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-prettyunits -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# opentsne -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# numba -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-cli -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-dplyr -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-cellranger -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-hms -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-backports -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-withr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-shiny -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-httpuv -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-r2d3 -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# scikit-learn -> libcblas[version='>=3.8.0,<4.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-xfun -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-openssl -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-profvis -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-catools -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# pytest-doctestplus -> numpy[version='>=1.10'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# numexpr -> numpy[version='>=1.18.1,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-base64enc -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# anaconda==2019.10 -> libgfortran==3.0.1=h93005f0_2
# r-rmarkdown -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-glue -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-bitops -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-tinytex -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-magrittr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-dbi -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-promises -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-markdown -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# pynndescent -> numpy[version='>=1.13'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# numpy-base -> blas=[build=openblas] -> libgfortran[version='>=4.0.0,<5.0.0.a0']
# r-askpass -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# astropy -> numpy[version='>=1.16'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# numpy -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-odbc -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# opencv -> hdf5[version='>=1.10.5,<1.10.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# blas -> openblas -> libgfortran[version='>=3.0,<4.0.0.a0']
# python-louvain -> numpy -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-httr -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# gfortran_osx-64 -> libgfortran[version='>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-xtable -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-bit -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-haven -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rcpp -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# blas -> libgfortran[version='>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# hdf5 -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-forge -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rlang -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-pki -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# mkl-service -> numpy[version='>=1.11.3,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-rsconnect -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# bokeh -> numpy[version='>=1.11.3'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# nltk -> numpy -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-yaml -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# scikit-image -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-tidyselect -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# anaconda==2019.10 -> hdf5==1.10.4=hfa1e0ec_0 -> libgfortran[version='>=3.0.1,<4.0.0.a0']
# r-miniui -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-packrat -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-base -> libgcc -> libgfortran==3.0.1
# r-forcats -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-dbplyr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# pywavelets -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-xml2 -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# pytables -> hdf5[version='>=1.10.5,<1.10.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-highr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-sparklyr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rappdirs -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-crayon -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# patsy -> numpy[version='>=1.4.0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-bit64 -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rematch -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-clipr -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rprojroot -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# pandas -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-rjava -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-digest -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# matplotlib -> numpy=1.11 -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# seaborn -> numpy[version='>=1.13.3'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# pyqtgraph -> numpy -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# scipy -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-later -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rcurl -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-base -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-readr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-htmltools -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-stringi -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-assertthat -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# numpy-base -> libgfortran[version='>=3.0.1,<4.0.0.a0']
# r-sys -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-generics -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# autograd -> numpy[version='>=1.10'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# mkl_random -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-knitr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-plogr -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-tidyr -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-r6 -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-jsonlite -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-sourcetools -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-readxl -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-ellipsis -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-pkgconfig -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-stringr -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-mongolite -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rjdbc -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# bottleneck -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# imageio -> numpy -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-progress -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# dask -> numpy[version='>=1.13.0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-curl -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# scipy -> libgcc -> libgfortran==3.0.1
# mkl_fft -> numpy[version='>=1.14.6,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# orange3==3.23.0 -> numpy[version='>=1.16.0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# r-purrr -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-utf8 -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-rstudioapi -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-htmlwidgets -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# r-fansi -> r-base[version='>=3.5,<3.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# statsmodels -> numpy[version='>=1.15.4,<2.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# bkcharts -> numpy[version='>=1.7.1'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0']
# r-rjsonio -> r-base[version='>=3.6,<3.7.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0|>=3.0.1']
# gsl -> libblas[version='>=3.8.0,<4.0a0'] -> libgfortran[version='3.0.1|>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
# h5py -> hdf5[version='>=1.10.5,<1.10.6.0a0'] -> libgfortran[version='>=3.0,<4.0.0.a0|>=3.0.1,<4.0.0.a0|>=4.0.0,<5.0.0.a0']
#
# Package libssh2 conflicts for:
# r-rmarkdown -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-mongolite -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-prettyunits -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-readr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-bh -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-catools -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-xml2 -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-htmltools -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-highr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-forcats -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-stringr -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-generics -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-stringi -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-odbc -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rlang -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-profvis -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-purrr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-pillar -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-cellranger -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-magrittr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-evaluate -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-dbplyr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-withr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# anaconda==2019.10 -> libssh2==1.8.2=ha12b0ac_0
# r-pkgconfig -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-bit64 -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-ellipsis -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-sparklyr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-httpuv -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-dbi -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rcurl -> libcurl[version='>=7.65.3,<8.0a0'] -> libssh2[version='1.*|1.8.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.9.0,<2.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-config -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-sys -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-haven -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-clipr -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-packrat -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-httr -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rematch -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-jsonlite -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-mime -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rappdirs -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-sourcetools -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# anaconda==2019.10 -> curl==7.65.3=ha441bb4_0 -> libssh2[version='>=1.8.2,<2.0a0']
# r-rprojroot -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-askpass -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rjdbc -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-knitr -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-promises -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-xtable -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-shiny -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-bit -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-fansi -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-assertthat -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-dplyr -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-utf8 -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rcpp -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-curl -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0|>=1.9.0,<2.0a0|1.8.*']
# r-backports -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rjava -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-r2d3 -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-forge -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-plogr -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-glue -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-base -> curl -> libssh2[version='1.8.*|>=1.9.0,<2.0a0']
# r-pki -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-crayon -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-progress -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-openssl -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-yaml -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-readxl -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-digest -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-xfun -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# pycurl -> libcurl[version='>=7.64.1,<8.0a0'] -> libssh2[version='1.*|1.8.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.9.0,<2.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-base64enc -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-later -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-tibble -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rstudioapi -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-r6 -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-bitops -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rjsonio -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# libcurl -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.9.0,<2.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# curl -> libssh2[version='1.*|1.8.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.9.0,<2.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-tinytex -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-tidyr -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-hms -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-htmlwidgets -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-miniui -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-markdown -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-blob -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-tidyselect -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-base -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-rsconnect -> r-base[version='>=3.6,<3.7.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
# r-cli -> r-base[version='>=3.5,<3.6.0a0'] -> libssh2[version='1.*|>=1.8.0,<1.9.0a0|>=1.8.2,<1.9.0a0|>=1.8.2,<2.0a0|>=1.8.0,<2.0a0']
#
# Package bwidget conflicts for:
# r-mongolite -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-profvis -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-sourcetools -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-stringi -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-bit -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-plogr -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-evaluate -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-base64enc -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-highr -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-digest -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-bit64 -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-blob -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-xml2 -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-base -> bwidget
# r-rlang -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-readr -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-rsconnect -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-xtable -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-config -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-clipr -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-rematch -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-tinytex -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-rjava -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-askpass -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-bh -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-stringr -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-r6 -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-httpuv -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-ellipsis -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-htmlwidgets -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-rprojroot -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-xfun -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-generics -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-tidyr -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-pki -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-tibble -> r-base[version='>=3.5,<3.6.0a0'] -> bwidget
# r-r2d3 -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# r-promises -> r-base[version='>=3.6,<3.7.0a0'] -> bwidget
# ...
# anaconda==2019.10 -> pytest-openfiles==0.4.0=py_0
#
# Package qt conflicts for:
# orange-canvas-core -> pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
# anaconda-navigator -> pyqt[version='>=5.6,<6.0a0'] -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
# qtconsole -> pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
# anaconda==2019.10 -> pyqt==5.9.2=py36h655552a_2 -> qt[version='5.9.*|>=5.9.6,<5.10.0a0']
# anaconda==2019.10 -> qt==5.9.7=h468cd18_1
# navigator-updater -> pyqt[version='>=5.6'] -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
# pyqtgraph -> pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
# spyder -> pyqt[version='>=5.6,<5.13'] -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
# anyqt -> pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
# pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
#
# Package pywavelets conflicts for:
# anaconda==2019.10 -> scikit-image==0.15.0=py36h0a44026_0 -> pywavelets[version='>=0.4.0']
# anaconda==2019.10 -> pywavelets==1.0.3[build='py37h1d22016_1|py36h1d22016_1|py27h1d22016_1']
# scikit-image -> pywavelets[version='>=0.4.0']
#
# Package spyder-kernels conflicts for:
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.8.1,<1.9.0|>=1.9.0,<1.10.0|>=1.8.1,<2.0.0|<1.0']
# anaconda==2019.10 -> spyder==3.3.6=py36_0 -> spyder-kernels[version='>=0.5.0,<1']
# anaconda==2019.10 -> spyder-kernels==0.5.2[build='py37_0|py36_0|py27_0']
#
# Package imageio conflicts for:
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0']
# anaconda==2019.10 -> scikit-image==0.15.0=py36h0a44026_0 -> imageio[version='>=2.1.0']
# anaconda==2019.10 -> imageio==2.6.0[build='py37_0|py36_0|py27_0']
#
# Package r-prettyunits conflicts for:
# r-progress -> r-prettyunits
# r-odbc -> r-blob[version='>=1.2.0'] -> r-prettyunits
# r-readxl -> r-progress -> r-prettyunits
# r-blob -> r-prettyunits
#
# Package snappy conflicts for:
# anaconda==2019.10 -> blosc==1.16.3=hd9629dc_0 -> snappy[version='>=1.1.7,<2.0a0']
# blosc -> snappy[version='1.1.6|>=1.1.7,<2.0a0']
# anaconda==2019.10 -> snappy==1.1.7=he62c110_3
# pytables -> blosc[version='>=1.16.3,<2.0a0'] -> snappy[version='1.1.6|>=1.1.7,<2.0a0']
#
# Package sortedcontainers conflicts for:
# sortedcollections -> sortedcontainers[version='>=2.0']
# attrs -> hypothesis -> sortedcontainers[version='>=2.1.0,<3.0.0']
# distributed -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# anaconda==2019.10 -> distributed==2.5.2=py_0 -> sortedcontainers[version='!=2.0.0,!=2.0.1|>=2.0']
# pytest-astropy -> hypothesis -> sortedcontainers[version='>=2.1.0,<3.0.0']
# dask -> distributed[version='>=2.12.0'] -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# anaconda==2019.10 -> sortedcontainers==2.1.0[build='py37_0|py36_0|py27_0']
# spyder -> intervaltree -> sortedcontainers
#
# Package llvmlite conflicts for:
# opentsne -> numba[version='>=0.38.1'] -> llvmlite[version='0.23.*|0.23.0|0.27.*|>=0.28.0,<0.29.0a0|>=0.28.0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.27.0,<0.28.0a0|>=0.26.0,<0.27.0a0|>=0.25.0,<0.26.0a0|>=0.31.0|0.24.*|0.30']
# pynndescent -> llvmlite==0.30
# numba -> llvmlite[version='0.20.*|0.21.*|0.21.0|0.23.0|0.27.*|>=0.28.0,<0.29.0a0|>=0.28.0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.27.0,<0.28.0a0|>=0.26.0,<0.27.0a0|>=0.25.0,<0.26.0a0|>=0.21.0,<0.21.1.0a0|>=0.31.0|0.24.*|0.23.*|0.22.*']
# anaconda==2019.10 -> numba==0.45.1=py36h6440ff4_0 -> llvmlite[version='>=0.29.0|>=0.29.0,<0.30.0a0']
# pynndescent -> numba==0.46 -> llvmlite[version='0.27.*|>=0.28.0,<0.29.0a0|>=0.28.0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0|>=0.30.0,<0.31.0a0|>=0.31.0,<0.32.0a0|>=0.31.0|>=0.27.0,<0.28.0a0|>=0.26.0,<0.27.0a0|>=0.25.0,<0.26.0a0']
# anaconda==2019.10 -> llvmlite==0.29.0[build='py37h98b8051_0|py36h98b8051_0|py27h98b8051_0']
#
# Package zict conflicts for:
# distributed -> zict[version='>=0.1.0|>=0.1.1|>=0.1.2|>=0.1.3']
# anaconda==2019.10 -> zict==1.0.0=py_0
# dask -> distributed[version='>=2.12.0'] -> zict[version='>=0.1.0|>=0.1.1|>=0.1.2|>=0.1.3']
# anaconda==2019.10 -> distributed==2.5.2=py_0 -> zict[version='>=0.1.3']
#
# Package blosc conflicts for:
# pytables -> blosc[version='>=1.14.3,<2.0a0|>=1.14.4,<2.0a0|>=1.15.0,<2.0a0|>=1.16.3,<2.0a0|>=1.17.0,<2.0a0']
# anaconda==2019.10 -> pytables==3.5.2=py36h5bccee9_1 -> blosc[version='>=1.16.3,<2.0a0']
# anaconda==2019.10 -> blosc==1.16.3=hd9629dc_0
#
# Package itsdangerous conflicts for:
# anaconda==2019.10 -> flask==1.1.1=py_0 -> itsdangerous[version='>=0.24']
# flask -> itsdangerous[version='>=0.21|>=0.24']
# anaconda==2019.10 -> itsdangerous==1.1.0[build='py37_0|py36_0|py27_0']
#
# Package ripgrep conflicts for:
# anaconda==2019.10 -> ripgrep==0.10.0=hc07d326_0
# conda-build -> ripgrep
#
# Package commonmark conflicts for:
# orange-widget-base -> orange-canvas-core[version='>=0.1.8'] -> commonmark
# orange-canvas-core -> commonmark
# orange3==3.23.0 -> orange-canvas-core[version='>=0.1.3,<0.2a'] -> commonmark
#
# Package r-withr conflicts for:
# rstudio==1.1.456 -> r-sparklyr[version='>=0.5.5'] -> r-withr
# r-sparklyr -> r-withr
#
# Package msgpack-python conflicts for:
# orange-canvas-core -> cachecontrol -> msgpack-python
# anaconda==2019.10 -> msgpack-python==0.6.1[build='py27h04f5b5a_1|py36h04f5b5a_1|py37h04f5b5a_1']
# dask -> distributed[version='>=2.12.0'] -> msgpack-python[version='<1.0.0|>=0.6.0']
# cachecontrol -> msgpack-python
# anaconda==2019.10 -> distributed==2.5.2=py_0 -> msgpack-python[version='<1.0.0']
# distributed -> msgpack-python[version='<1.0.0|>=0.6.0']
#
# Package r-knitr conflicts for:
# rstudio==1.1.456 -> r-knitr[version='>=1.14']
# r-rmarkdown -> r-knitr[version='>=1.11|>=1.12|>=1.14|>=1.18|>=1.22|>=1.6']
# rstudio==1.1.456 -> r-rmarkdown[version='>=1.6'] -> r-knitr[version='>=1.18|>=1.22']
#
# Package compiler-rt_osx-64 conflicts for:
# clang_osx-64 -> compiler-rt_osx-64[version='9.0.0.*|9.0.1.*']
# r-base -> clang_osx-64[version='>=9'] -> compiler-rt_osx-64[version='9.0.0.*|9.0.1.*']
# clangxx_osx-64 -> clang_osx-64[version='>=9.0.1,<9.0.2.0a0'] -> compiler-rt_osx-64[version='9.0.0.*|9.0.1.*']
# compiler-rt -> compiler-rt_osx-64[version='9.0.0.*|9.0.1.*']
#
# Package jdcal conflicts for:
# anaconda==2019.10 -> openpyxl==3.0.0=py_0 -> jdcal
# openpyxl -> jdcal
# anaconda==2019.10 -> jdcal==1.4.1=py_0
#
# Package gfortran_impl_osx-64 conflicts for:
# r-base -> gfortran_osx-64=7 -> gfortran_impl_osx-64==7.3.0
# gfortran_osx-64 -> gfortran_impl_osx-64==7.3.0
#
# Package pyflakes conflicts for:
# spyder -> python-language-server[version='>=0.31.9,<0.32.0'] -> pyflakes[version='>=1.6.0']
# spyder -> pyflakes
# anaconda==2019.10 -> spyder==3.3.6=py36_0 -> pyflakes
# anaconda==2019.10 -> pyflakes==2.1.1[build='py37_0|py36_0|py27_0']
#
# Package bkcharts conflicts for:
# anaconda==2019.10 -> bkcharts==0.2[build='py37_0|py27haafc882_0|py36h073222e_0']
# dask -> bokeh -> bkcharts[version='>=0.2']
# distributed -> bokeh[version='>=0.12.3'] -> bkcharts[version='>=0.2']
# bokeh -> bkcharts[version='>=0.2']
#
# Package libuuid conflicts for:
# cairo -> fontconfig[version='>=2.13.0,<3.0a0'] -> libuuid[version='>=1.0.3,<2.0a0']
# r-rmarkdown -> xorg-libsm=1.2 -> libuuid=1.0
# fontconfig -> libuuid[version='>=1.0.3,<2.0a0']
# pango -> fontconfig[version='>=2.13.0,<3.0a0'] -> libuuid[version='>=1.0.3,<2.0a0']
#
# Package backcall conflicts for:
# anaconda==2019.10 -> ipython==7.8.0=py36h39e3cac_0 -> backcall
# ipython -> backcall
# jupyter_console -> ipython -> backcall
# ipywidgets -> ipython[version='>=4.0.0'] -> backcall
# ipykernel -> ipython[version='>=5.0'] -> backcall
# anaconda==2019.10 -> backcall==0.1.0[build='py37_0|py36_0']
#
# Package r-formatr conflicts for:
# r-rmarkdown -> r-knitr[version='>=1.12'] -> r-formatr
# r-knitr -> r-formatr
#
# Package werkzeug conflicts for:
# anaconda==2019.10 -> werkzeug==0.16.0=py_0
# flask -> werkzeug[version='>=0.14|>=0.15|>=0.7']
# anaconda==2019.10 -> flask==1.1.1=py_0 -> werkzeug[version='>=0.14']
#
# Package r-openssl conflicts for:
# r-mongolite -> r-openssl[version='>=0.9.4|>=1.0']
# r-httr -> r-openssl[version='>=0.8']
# r-sparklyr -> r-openssl[version='>=0.8']
# rstudio==1.1.456 -> r-mongolite[version='>=0.8'] -> r-openssl[version='>=0.8|>=0.9.4|>=1.0']
# r-rsconnect -> r-openssl
#
# Package jupyter_console conflicts for:
# jupyter -> jupyter_console
# anaconda==2019.10 -> jupyter==1.0.0=py36_7 -> jupyter_console
# anaconda==2019.10 -> jupyter_console[version='5.2.0|6.0.0|6.0.0',build='py37_0|py27_1|py36_0']
#
# Package r-zeallot conflicts for:
# r-hms -> r-vctrs[version='>=0.2.0'] -> r-zeallot
# r-tidyr -> r-vctrs[version='>=0.2.0'] -> r-zeallot
# r-blob -> r-vctrs[version='>=0.2.1'] -> r-zeallot
# r-tidyselect -> r-vctrs[version='>=0.2.2'] -> r-zeallot
# r-pillar -> r-vctrs -> r-zeallot
#
# Package backports.tempfile conflicts for:
# conda-build -> conda-verify -> backports.tempfile
# conda-verify -> backports.tempfile
#
# Package r-r2d3 conflicts for:
# rstudio==1.1.456 -> r-sparklyr[version='>=0.5.5'] -> r-r2d3
# r-sparklyr -> r-r2d3
#
# Package orange-canvas-core conflicts for:
# orange3==3.23.0 -> orange-widget-base[version='>=4.0a,<4.1a'] -> orange-canvas-core
# orange-widget-base -> orange-canvas-core[version='>=0.1.8']
# orange3==3.23.0 -> orange-canvas-core[version='>=0.1.3,<0.2a']
#
# Package sphinxcontrib-devhelp conflicts for:
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-devhelp
# anaconda==2019.10 -> sphinxcontrib-devhelp==1.0.1=py_0
# sphinx -> sphinxcontrib-devhelp
# anaconda==2019.10 -> sphinx==2.2.0=py_0 -> sphinxcontrib-devhelp
# numpydoc -> sphinx -> sphinxcontrib-devhelp
#
# Package selectors2 conflicts for:
# spyder-kernels -> wurlitzer[version='>=1.0.3'] -> selectors2
# wurlitzer -> selectors2
#
# Package dask conflicts for:
# distributed -> dask[version='>=0.10.0|>=0.11.0|>=0.11.1|>=0.12.0|>=0.13.0|>=0.14.0|>=0.14.1|>=0.9.0']
# scikit-image -> dask[version='>=0.5']
# anaconda==2019.10 -> dask[version='1.2.2|2.5.2',build=py_0]
#
# Package pylint conflicts for:
# spyder -> pylint[version='>=0.25']
# anaconda==2019.10 -> spyder==3.3.6=py36_0 -> pylint
# anaconda==2019.10 -> pylint[version='1.9.2|2.4.2|2.4.2',build='py37_0|py36_0|py27_0']
#
# Package nspr conflicts for:
# qt -> nspr[version='>=4.20,<5.0a0']
# pyqt -> qt[version='>=5.12.5,<5.13.0a0'] -> nspr[version='>=4.20,<5.0a0']
#
# Package r-packrat conflicts for:
# rstudio==1.1.456 -> r-packrat[version='>=0.4.8_1']
# r-rsconnect -> r-packrat[version='>=0.4.8_1']
#
# Package pyqtgraph conflicts for:
# orange-widget-base -> pyqtgraph
# orange3==3.23.0 -> orange-widget-base[version='>=4.0a,<4.1a'] -> pyqtgraph
# orange3==3.23.0 -> pyqtgraph[version='>=0.10.0']
#
# Package r-blob conflicts for:
# rstudio==1.1.456 -> r-odbc[version='>=1.1.1'] -> r-blob[version='>=1.1.0|>=1.2.0']
# r-odbc -> r-blob[version='>=1.1.0|>=1.2.0']
#
# Package harfbuzz conflicts for:
# pango -> harfbuzz[version='1.3.*|1.4.*|1.7.*|>=1.7.6,<1.8.0a0|>=1.8.4,<2.0a0|>=1.8.6,<2.0a0|>=1.9.0,<2.0a0|>=2.3.0,<3.0a0|>=2.4.0,<3.0a0|>=1.7.6,<2.0a0|>=1.7.4,<2.0a0|>=1.5.0,<2.0a0']
# opencv -> harfbuzz[version='1.3.*|1.3.4|1.7.*|>=1.7.6,<1.8.0a0|>=1.8.5,<2.0a0|>=1.9.0,<2.0a0|>=2.3.1,<3.0a0|>=2.4.0,<3.0a0|>=1.5.0,<2.0a0']
# r-base -> pango[version='>=1.42.4,<1.43.0a0'] -> harfbuzz[version='1.3.*|1.4.*|1.7.*|>=1.7.6,<1.8.0a0|>=1.7.6,<2.0a0|>=2.4.0,<3.0a0|>=2.3.0,<3.0a0|>=1.9.0,<2.0a0|>=1.8.6,<2.0a0|>=1.8.4,<2.0a0|>=1.5.0,<2.0a0|>=1.7.4,<2.0a0']
#
# Package clyent conflicts for:
# anaconda==2019.10 -> anaconda-client==1.7.2=py36_0 -> clyent[version='>=1.2.2']
# anaconda-navigator -> anaconda-client[version='>=1.6.14'] -> clyent[version='>=1.2.0|>=1.2.2']
# anaconda-project -> anaconda-client -> clyent[version='>=1.2.0|>=1.2.2']
# anaconda-client -> clyent[version='>=1.2.0|>=1.2.2']
# anaconda==2019.10 -> clyent==1.2.2[build='py37_1|py27_1|py36_1']
#
# Package filelock conflicts for:
# conda-build -> filelock
# anaconda==2019.10 -> filelock==3.0.12=py_0
#
# Package python-pathlib2 conflicts for:
# spyder -> pickleshare[version='>=0.4'] -> python-pathlib2
# ipython -> pickleshare -> python-pathlib2
# pickleshare -> python-pathlib2
#
# Package mpi conflicts for:
# hdf5 -> mpich[version='>=3.3,<3.4.0a0'] -> mpi==1.0[build='mpich|openmpi']
# h5py -> openmpi[version='>=4.0.2,<4.1.0a0'] -> mpi==1.0[build='mpich|openmpi']
#
# Package greenlet conflicts for:
# anaconda==2019.10 -> greenlet==0.4.15[build='py37h1de35cc_0|py27h1de35cc_0|py36h1de35cc_0']
# gevent -> greenlet[version='>=0.4.10|>=0.4.13|>=0.4.14']
# anaconda==2019.10 -> gevent==1.4.0=py36h1de35cc_0 -> greenlet[version='>=0.4.14']
#
# Package font-ttf-ubuntu conflicts for:
# fonts-anaconda -> font-ttf-ubuntu
# rstudio==1.1.456 -> fonts-anaconda -> font-ttf-ubuntu
#
# Package r-sys conflicts for:
# r-askpass -> r-sys[version='>=2.1']
# r-openssl -> r-askpass -> r-sys[version='>=2.1']
#
# Package font-ttf-inconsolata conflicts for:
# rstudio==1.1.456 -> fonts-anaconda -> font-ttf-inconsolata
# fonts-anaconda -> font-ttf-inconsolata
#
# Package xlrd conflicts for:
# anaconda==2019.10 -> xlrd==1.2.0[build='py37_0|py36_0|py27_0']
# orange3==3.23.0 -> xlrd[version='>=0.9.2']
#
# Package bottleneck conflicts for:
# orange3==3.23.0 -> bottleneck[version='>=1.0.0']
# anaconda==2019.10 -> bottleneck==1.2.1[build='py37h1d22016_1|py36h1d22016_1|py27h1d22016_1']
#
# Package jupyterlab conflicts for:
# anaconda==2019.10 -> jupyterlab[version='0.33.11|1.1.4',build='pyhf63ae98_0|py27_0']
# _ipyw_jlab_nb_ext_conf -> jupyterlab
#
# Package lockfile conflicts for:
# orange-canvas-core -> lockfile[version='>=0.9']
# orange3==3.23.0 -> orange-canvas-core[version='>=0.1.3,<0.2a'] -> lockfile[version='>=0.9']
# orange-widget-base -> orange-canvas-core[version='>=0.1.8'] -> lockfile[version='>=0.9']
#
# Package giflib conflicts for:
# opencv -> libwebp[version='>=1.0.0,<1.1.0a0'] -> giflib[version='>=5.1.4,<5.2.0a0|>=5.1.7,<5.1.8.0a0|>=5.2.1,<5.3.0a0']
# libtiff -> libwebp -> giflib[version='>=5.1.4,<5.2.0a0|>=5.1.7,<5.1.8.0a0|>=5.2.1,<5.3.0a0']
#
# Package r-generics conflicts for:
# r-sparklyr -> r-generics
# rstudio==1.1.456 -> r-sparklyr[version='>=0.5.5'] -> r-generics
# r-sparklyr -> r-broom -> r-generics[version='>=0.0.2']
#
# Package r-markdown conflicts for:
# rstudio==1.1.456 -> r-knitr[version='>=1.14'] -> r-markdown
# r-knitr -> r-markdown
# r-rmarkdown -> r-knitr[version='>=1.22'] -> r-markdown
# rstudio==1.1.456 -> r-markdown[version='>=0.7']
#
# Package pycparser conflicts for:
# gevent -> cffi[version='>=1.11.5'] -> pycparser
# cryptography -> cffi[version='>=1.8,!=1.11.3'] -> pycparser
# cffi -> pycparser
# anaconda==2019.10 -> cffi==1.12.3=py36hb5b8e2f_0 -> pycparser
# anaconda==2019.10 -> pycparser==2.19[build='py37_0|py36_0|py27_0']
#
# Package r-rjava conflicts for:
# r-rjdbc -> r-rjava[version='>=0.4_15']
# rstudio==1.1.456 -> r-rjava[version='>=0.4_15']
#
# Package r-catools conflicts for:
# r-rmarkdown -> r-catools
# rstudio==1.1.456 -> r-catools[version='>=1.14']
# rstudio==1.1.456 -> r-rmarkdown[version='>=1.6'] -> r-catools
#
# Package r-tinytex conflicts for:
# r-rmarkdown -> r-tinytex[version='>=0.11|>=0.3']
# rstudio==1.1.456 -> r-rmarkdown[version='>=1.6'] -> r-tinytex[version='>=0.11|>=0.3']
#
# Package qtawesome conflicts for:
# spyder -> qtawesome[version='>=0.4.1|>=0.5.7']
# anaconda==2019.10 -> qtawesome==0.6.0=py_0
# anaconda==2019.10 -> spyder==3.3.6=py36_0 -> qtawesome[version='>=0.5.7']
#
# Package pep8 conflicts for:
# spyder -> pep8
# anaconda==2019.10 -> pep8==1.7.1[build='py37_0|py36_0|py27_0']
#
# Package pynndescent conflicts for:
# orange3==3.23.0 -> opentsne[version='>=0.3.11'] -> pynndescent[version='>=0.3']
# opentsne -> pynndescent[version='>=0.3']
#
# Package numexpr conflicts for:
# anaconda==2019.10 -> pytables==3.5.2=py36h5bccee9_1 -> numexpr
# pytables -> numexpr
# anaconda==2019.10 -> numexpr==2.7.0[build='py37h7413580_0|py27h7413580_0|py36h7413580_0']
#
# Package pkg-config conflicts for:
# glib -> pkg-config
# harfbuzz -> glib=2 -> pkg-config
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import print_function
import cv2 as cv
import argparse

def detectAndDisplay(frame):
    frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    frame_gray = cv.equalizeHist(frame_gray)

    #-- Detect faces
    faces = face_cascade.detectMultiScale(frame_gray)
    for (x,y,w,h) in faces:
        center = (x + w//2, y + h//2)
        frame = cv.ellipse(frame, center, (w//2, h//2), 0, 0, 360, (255, 0, 255), 4)

        faceROI = frame_gray[y:y+h,x:x+w]
        # #-- In each face, detect eyes
        # eyes = eyes_cascade.detectMultiScale(faceROI)
        # for (x2,y2,w2,h2) in eyes:
        #     eye_center = (x + x2 + w2//2, y + y2 + h2//2)
        #     radius = int(round((w2 + h2)*0.25))
        #     frame = cv.circle(frame, eye_center, radius, (255, 0, 0 ), 4)

    cv.imshow('Capture - Face detection', frame)

parser = argparse.ArgumentParser(description='Code for Cascade Classifier tutorial.')
parser.add_argument('--face_cascade', help='Path to face cascade.', default='opencv/data/haarcascades/haarcascade_frontalface_alt.xml')
parser.add_argument('--eyes_cascade', help='Path to eyes cascade.', default='opencv/data/haarcascades/haarcascade_eye_tree_eyeglasses.xml')
parser.add_argument('--camera', help='Camera divide number.', type=int, default=0)
args = parser.parse_args()

face_cascade_name = args.face_cascade
eyes_cascade_name = args.eyes_cascade

face_cascade = cv.CascadeClassifier()
eyes_cascade = cv.CascadeClassifier()

#-- 1. Load the cascades
if not face_cascade.load(cv.samples.findFile(face_cascade_name)):
    print('--(!)Error loading face cascade')
    exit(0)
if not eyes_cascade.load(cv.samples.findFile(eyes_cascade_name)):
    print('--(!)Error loading eyes cascade')
    exit(0)

camera_device = args.camera
#-- 2. Read the video stream
cap = cv.VideoCapture(camera_device)
if not cap.isOpened:
    print('--(!)Error opening video capture')
    exit(0)

while True:
    ret, frame = cap.read()
    if frame is None:
        print('--(!) No captured frame -- Break!')
        break

    detectAndDisplay(frame)

    if cv.waitKey(10) == 27:
        break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-21f36764fe57> in <module>
#       1 from __future__ import print_function
# ----> 2 import cv2 as cv
#       3 import argparse
#       4
#       5 def detectAndDisplay(frame):
#
# ModuleNotFoundError: No module named 'cv2'
